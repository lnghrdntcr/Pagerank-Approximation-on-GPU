# %%
import pandas as pd
import seaborn as sns
import numpy as np
from os import listdir
from itertools import product
import matplotlib.pyplot as plt
sns.set_context("talk")
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Execution Times

# %%
graph_types = ["scf", "gnp", "smw"]
algo_types  = ["fixed", "floating"]
optim_type  = ['no_optim', 'l2_norm_bitmask', 'l2_norm']

measurements = pd.DataFrame()

for g in graph_types: 
    for a in algo_types: 
        csvs = [f"../new_ds/measurements/{g}/{a}/m/{filename}" for filename in listdir(f"../new_ds/measurements/{g}/{a}/m") if '.csv' in filename]
        temp = pd.DataFrame()
        for el in csvs:
            temp = pd.read_csv(el)
            temp["algo"] = a
            temp["graph"] = g
            val = el.split('/')[-1].split('.')[0][:-1]
            
            if val not in optim_type: 
                val = val[:-1]
            temp["optim"] = val
            
            measurements = measurements.append(temp, ignore_index=True)

# %%
measurements.head()
# Out:
#              Type    Time(%)       Time  Calls      Avg      Min      Max  \
# 0  GPU activities  46.929383  12.827382    111  115.562  113.376  117.377
# 1  GPU activities  14.994459   4.098491    111   36.923   36.513   37.376
# 2  GPU activities  14.252681   3.895738    111   35.096   34.656   35.712
# 3  GPU activities   8.233438   2.250476    111   20.274   19.904   20.480
# 4  GPU activities   6.197425   1.693965    111   15.260   15.104   15.520
#
#                                                 Name   algo graph  \
# 0  void d_update_fixed_spmv<__int64>(__int64*, __...  fixed   scf
# 1  void d_fixed_axpb<__int64>(__int64*, __int64, ...  fixed   scf
# 2  void d_update_fixed_compute_error<__int64>(__i...  fixed   scf
# 3  void thrust::cuda_cub::cub::DeviceReduceKernel...  fixed   scf
# 4  void thrust::cuda_cub::cub::DeviceReduceKernel...  fixed   scf
#
#              optim
# 0  l2_norm_bitmask
# 1  l2_norm_bitmask
# 2  l2_norm_bitmask
# 3  l2_norm_bitmask
# 4  l2_norm_bitmask

# %%
measurements = measurements[measurements["Type"] == "GPU activities"].reset_index()
measurements = measurements[['Time', 'Name', 'algo', 'graph', 'optim']]

# %%
measurements = measurements.groupby(["algo", "optim", "graph", "Name"]).agg({
    "Time": "mean", 
}).reset_index()

# %%
measurements.head()
# Out:
#     algo    optim graph                                               Name  \
# 0  fixed  l2_norm   gnp                                 [CUDA memcpy DtoD]
# 1  fixed  l2_norm   gnp                                 [CUDA memcpy DtoH]
# 2  fixed  l2_norm   gnp                                 [CUDA memcpy HtoD]
# 3  fixed  l2_norm   gnp  d_fixed_set_dangling_bitmap(bool*, int*, unsig...
# 4  fixed  l2_norm   gnp  void d_fixed_axpb<__int64>(__int64*, __int64, ...
#
#        Time
# 0  0.913799
# 1  0.320569
# 2  0.339529
# 3  0.067530
# 4  3.070938

# %%
measurements["final_exec_time"] = 0
measurements["new_idx"] = list(range(measurements.shape[0]))

# %%
for algo, graph, optim in product(algo_types,graph_types, optim_type): 
    partial_gpu_act = measurements[(measurements["algo"] == algo) & (measurements["graph"] == graph) & (measurements["optim"] == optim)]
    idx             = partial_gpu_act["new_idx"]
    if partial_gpu_act.shape[0] != 0: 
        total_exec_time = partial_gpu_act.apply(lambda x: x["Time"], axis=1).sum()
        print(f"{algo} point on {graph} with {optim} -> {str(total_exec_time)}ms")
        measurements.loc[idx, "final_exec_time"] = total_exec_time
# Out:
# fixed point on scf with no_optim -> 41.7707018ms
# fixed point on scf with l2_norm_bitmask -> 27.385081600000003ms
# fixed point on scf with l2_norm -> 26.8294792ms
# fixed point on gnp with no_optim -> 45.60493699999999ms
# fixed point on gnp with l2_norm_bitmask -> 23.314014199999995ms
# fixed point on gnp with l2_norm -> 22.9838213ms
# fixed point on smw with no_optim -> 47.2750244ms
# fixed point on smw with l2_norm_bitmask -> 16.4118467ms
# fixed point on smw with l2_norm -> 16.0101839ms
# floating point on scf with no_optim -> 16.4141189ms
# floating point on scf with l2_norm_bitmask -> 16.9769043ms
# floating point on scf with l2_norm -> 16.392527799999996ms
# floating point on gnp with no_optim -> 18.023422500000002ms
# floating point on gnp with l2_norm_bitmask -> 18.699596899999996ms
# floating point on gnp with l2_norm -> 18.293412500000006ms
# floating point on smw with no_optim -> 21.0722966ms
# floating point on smw with l2_norm_bitmask -> 21.855249300000004ms
# floating point on smw with l2_norm -> 21.319073999999993ms

# %%
measurements = measurements[['Time','Name', 'algo', 'graph', 'optim', 'final_exec_time']]

# %%
for g_idx, rest in measurements.groupby("graph"): 
    print(f"Fastest for {g_idx}")
    print("\t", rest[rest["final_exec_time"] == rest["final_exec_time"].min()]["algo"].unique()[0], rest[rest["final_exec_time"] == rest["final_exec_time"].min()]["optim"].unique()[0])
# Out:
# Fastest for gnp
# 	 floating no_optim
# Fastest for scf
# 	 floating l2_norm
# Fastest for smw
# 	 fixed l2_norm

# %%
for g_idx, rest in measurements.groupby(["graph", "algo", "optim"]):
    formatted_fn_names = list(map(lambda x: x.split('<')[0], rest["Name"].unique()))
    plt.figure(figsize=(20, 10))
    x =  rest[["Time", "Name"]]
    x["Name"] = x["Name"].apply(lambda x: x.split("<")[0])
    x = x.set_index('Name')
    ax = x.sort_values("Time", ascending=False).plot(kind="bar", title=f"Graph: {g_idx[0]} Implementation: {g_idx[1]} point Optimization: {g_idx[2]}")
    ax.set_xlabel("Time (ms)")
    plt.savefig(f'figures/function_execution_time/{g_idx[0]}_{g_idx[1]}_{g_idx[2]}.png')

# %%
measurements.head()
# Out:
#        Time                                               Name   algo graph  \
# 0  0.913799                                 [CUDA memcpy DtoD]  fixed   gnp
# 1  0.320569                                 [CUDA memcpy DtoH]  fixed   gnp
# 2  0.339529                                 [CUDA memcpy HtoD]  fixed   gnp
# 3  0.067530  d_fixed_set_dangling_bitmap(bool*, int*, unsig...  fixed   gnp
# 4  3.070938  void d_fixed_axpb<__int64>(__int64*, __int64, ...  fixed   gnp
#
#      optim  final_exec_time
# 0  l2_norm        22.983821
# 1  l2_norm        22.983821
# 2  l2_norm        22.983821
# 3  l2_norm        22.983821
# 4  l2_norm        22.983821

# %%
times = pd.DataFrame(columns=["graph", "algo", "optim", "time"])


for g_idx, rest in measurements.groupby(["graph", "algo", "optim"]):
    graph, algo, optim = g_idx
    ds = {}
    ds["graph"] = graph
    ds["algo"] = algo
    ds["optim"] = optim
    ds["time"] = rest["final_exec_time"].unique()[0]
    times = times.append(ds, ignore_index=True)

# %%
times.head()
# Out:
#   graph      algo            optim       time
# 0   gnp     fixed          l2_norm  22.983821
# 1   gnp     fixed  l2_norm_bitmask  23.314014
# 2   gnp     fixed         no_optim  45.604937
# 3   gnp  floating          l2_norm  18.293413
# 4   gnp  floating  l2_norm_bitmask  18.699597

# %%
for idx, rest in times.groupby(["graph"]):
    plt.figure(figsize=(20, 10))
    ax = sns.barplot(x="algo", y="time", hue="optim", data=rest)
    ax.set_ylabel("Time (ms)")
    ax.set_title(idx)
    plt.savefig(f'figures/execution_time_all/{idx}.png')

# %%
best_performers = pd.DataFrame(columns=["graph","algo", "optim", "time"])

for g_idx, rest in times.groupby(["graph", "algo"]): 
    graph, algo = g_idx
    ds = {}
    ds["graph"] = graph
    ds["algo"] = algo
    ds["optim"] = rest[rest["time"] == rest["time"].min()]["optim"].values[0]
    ds["time"] = rest["time"].unique()[0]
    
    best_performers = best_performers.append(ds, ignore_index=True)
    
parra = {
    "graph": ["gnp", "scf", "smw"],
    "algo": ["baseline", "baseline", "baseline"],
    "optim": ["default","default","default"],
    "time": [109, 116, 85]
}

p_ds = pd.DataFrame(parra)
"""
networkx = {
    "graph": ["gnp", "scf", "smw"],
    "algo": ["nx", "nx", "nx"],
    "optim": ["default","default","default"],
    "time": [1.525076150894165 * 1000, 1.1051805019 * 1000, 1.12183453 * 1000]
}

nx_ds = pd.DataFrame(networkx)
"""
print()

# %%
#final = pd.concat([best_performers, p_ds])
#final = pd.concat([final, nx_ds])
#final = best_performers.append([p_ds, nx_ds])
final = best_performers.append([p_ds])
final.head()
# Out:
#   graph      algo     optim       time
# 0   gnp     fixed   l2_norm  22.983821
# 1   gnp  floating  no_optim  18.293413
# 2   scf     fixed   l2_norm  26.829479
# 3   scf  floating   l2_norm  16.392528
# 4   smw     fixed   l2_norm  16.010184

# %%
for idx, el in final.groupby("graph"): 
    plt.figure(figsize=(20, 10))
    ax = sns.barplot(x="algo", y="time", data=el)      
    ax.set_ylabel("Time (ms)")
    ax.set_title(idx)
    ax.set_xlabel("fixed point with {}, floating point with {}".format(el[el["algo"] == "fixed"]["optim"].values[0], el[el["algo"] == "floating"]["optim"].values[0]))
    plt.savefig(f'figures/execution_time/{idx}_cmp.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-b2d59109ea07> in <module>
#      13     #    print((el[el["algo"] == 'baseline']["time"].values[0]) / row.time )
#      14     #    ax.text(row.algo,row.time,(row.time / (el[el["algo"] == 'baseline']["time"].values[0])))
# ---> 15     plt.savefig(f'figures/execution_time/{idx}_cmp.png')
#      16
#      17
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     687 def savefig(*args, **kwargs):
#     688     fig = gcf()
# --> 689     res = fig.savefig(*args, **kwargs)
#     690     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     691     return res
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, frameon, transparent, **kwargs)
#    2092             self.set_frameon(frameon)
#    2093
# -> 2094         self.canvas.print_figure(fname, **kwargs)
#    2095
#    2096         if frameon:
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2073                     orientation=orientation,
#    2074                     bbox_inches_restore=_bbox_inches_restore,
# -> 2075                     **kwargs)
#    2076             finally:
#    2077                 if bbox_inches and restore_bbox:
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     508
#     509         """
# --> 510         FigureCanvasAgg.draw(self)
#     511         renderer = self.get_renderer()
#     512
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/text.py in draw(self, renderer)
#     707
#     708         with _wrap_text(self) as textobj:
# --> 709             bbox, info, descent = textobj._get_layout(renderer)
#     710             trans = textobj.get_transform()
#     711
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     284         of a rotated text when necessary.
#     285         """
# --> 286         key = self.get_prop_tup(renderer=renderer)
#     287         if key in self._cached:
#     288             return self._cached[key]
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/text.py in get_prop_tup(self, renderer)
#     869         need to know if the text has changed.
#     870         """
# --> 871         x, y = self.get_unitless_position()
#     872         renderer = renderer or self._renderer
#     873         return (x, y, self.get_text(), self._color,
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/text.py in get_unitless_position(self)
#     851         # This will get the position with all unit information stripped away.
#     852         # This is here for convenience since it is done in several locations.
# --> 853         x = float(self.convert_xunits(self._x))
#     854         y = float(self.convert_yunits(self._y))
#     855         return x, y
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/artist.py in convert_xunits(self, x)
#     184         if ax is None or ax.xaxis is None:
#     185             return x
# --> 186         return ax.xaxis.convert_units(x)
#     187
#     188     def convert_yunits(self, y):
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1528             return x
#    1529
# -> 1530         ret = self.converter.convert(x, self.units, self)
#    1531         return ret
#    1532
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      51
#      52         # force an update so it also does type checking
# ---> 53         unit.update(values)
#      54
#      55         str2idx = np.vectorize(unit._mapping.__getitem__,
#
# AttributeError: 'NoneType' object has no attribute 'update'
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fe4614e7c80> (for post_execute):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for f_mgr in cls.get_all_fig_managers():
#     131             if force or f_mgr.canvas.figure.stale:
# --> 132                 f_mgr.canvas.draw_idle()
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/text.py in draw(self, renderer)
#     707
#     708         with _wrap_text(self) as textobj:
# --> 709             bbox, info, descent = textobj._get_layout(renderer)
#     710             trans = textobj.get_transform()
#     711
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     284         of a rotated text when necessary.
#     285         """
# --> 286         key = self.get_prop_tup(renderer=renderer)
#     287         if key in self._cached:
#     288             return self._cached[key]
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/text.py in get_prop_tup(self, renderer)
#     869         need to know if the text has changed.
#     870         """
# --> 871         x, y = self.get_unitless_position()
#     872         renderer = renderer or self._renderer
#     873         return (x, y, self.get_text(), self._color,
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/text.py in get_unitless_position(self)
#     851         # This will get the position with all unit information stripped away.
#     852         # This is here for convenience since it is done in several locations.
# --> 853         x = float(self.convert_xunits(self._x))
#     854         y = float(self.convert_yunits(self._y))
#     855         return x, y
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/artist.py in convert_xunits(self, x)
#     184         if ax is None or ax.xaxis is None:
#     185             return x
# --> 186         return ax.xaxis.convert_units(x)
#     187
#     188     def convert_yunits(self, y):
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1528             return x
#    1529
# -> 1530         ret = self.converter.convert(x, self.units, self)
#    1531         return ret
#    1532
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      51
#      52         # force an update so it also does type checking
# ---> 53         unit.update(values)
#      54
#      55         str2idx = np.vectorize(unit._mapping.__getitem__,
#
# AttributeError: 'NoneType' object has no attribute 'update'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/anaconda/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /opt/anaconda/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /opt/anaconda/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2047                         orientation=orientation,
#    2048                         dryrun=True,
# -> 2049                         **kwargs)
#    2050                     renderer = self.figure._cachedRenderer
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     508
#     509         """
# --> 510         FigureCanvasAgg.draw(self)
#     511         renderer = self.get_renderer()
#     512
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/text.py in draw(self, renderer)
#     707
#     708         with _wrap_text(self) as textobj:
# --> 709             bbox, info, descent = textobj._get_layout(renderer)
#     710             trans = textobj.get_transform()
#     711
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     284         of a rotated text when necessary.
#     285         """
# --> 286         key = self.get_prop_tup(renderer=renderer)
#     287         if key in self._cached:
#     288             return self._cached[key]
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/text.py in get_prop_tup(self, renderer)
#     869         need to know if the text has changed.
#     870         """
# --> 871         x, y = self.get_unitless_position()
#     872         renderer = renderer or self._renderer
#     873         return (x, y, self.get_text(), self._color,
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/text.py in get_unitless_position(self)
#     851         # This will get the position with all unit information stripped away.
#     852         # This is here for convenience since it is done in several locations.
# --> 853         x = float(self.convert_xunits(self._x))
#     854         y = float(self.convert_yunits(self._y))
#     855         return x, y
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/artist.py in convert_xunits(self, x)
#     184         if ax is None or ax.xaxis is None:
#     185             return x
# --> 186         return ax.xaxis.convert_units(x)
#     187
#     188     def convert_yunits(self, y):
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1528             return x
#    1529
# -> 1530         ret = self.converter.convert(x, self.units, self)
#    1531         return ret
#    1532
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      51
#      52         # force an update so it also does type checking
# ---> 53         unit.update(values)
#      54
#      55         str2idx = np.vectorize(unit._mapping.__getitem__,
#
# AttributeError: 'NoneType' object has no attribute 'update'
